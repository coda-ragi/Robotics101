# %%
import numpy as np

# Verify NumPy array creation
print("NumPy version:", np.__version__)

# Create and display a baseline Identity matrix 
R_identity = np.eye(3)
print("\nIdentity Rotation Matrix:")
print(R_identity)
# Out:
# NumPy version: 2.5.1
#
# Identity Rotation Matrix:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
import numpy as np
# Import the spatial math tools and visualization functions directly from base
from spatialmath.base import trplot, rotx, roty, rotz, plotvol3 

# Initialize the 3D plot volume first
plotvol3(new=True)

# Plot the baseline identity matrix frame
R_identity = np.eye(3)
trplot(R_identity);

# Plot a frame rotated by pi/2 about the x-axis
R_x = rotx(np.pi/2)
trplot(R_x);
